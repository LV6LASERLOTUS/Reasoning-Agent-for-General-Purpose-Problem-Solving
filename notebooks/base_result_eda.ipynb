# %% [markdown]
# ### Import Libraries

# %%
import os, json, textwrap, re, time
import pandas as pd
from tqdm import tqdm,trange

import requests 

from typing import Any

# %% [markdown]
# ### Constants

# %%
API_KEY  = os.getenv("OPENAI_API_KEY", "cse476")
API_BASE = os.getenv("API_BASE", "http://10.4.58.53:41701/v1")  
MODEL    = os.getenv("MODEL_NAME", "bens_model")

# %% [markdown]
# ### Useful Methods

# %%
def call_model(prompt: str,
               system: str = "You are Qwen, created by Alibaba Cloud. You are a helpful assistant. Reply with only the final answer—no explanation.",
               model: str = MODEL,
               temperature: float = 0.0,
               timeout: int = 60) -> dict[str, Any]:
    """
    Calls an OpenAI-style /v1/chat/completions endpoint and returns:
    { 'ok': bool, 'text': str or None, 'raw': dict or None, 'status': int, 'error': str or None, 'headers': dict }
    """
    url = f"{API_BASE}/chat/completions"
    headers = {
        "Authorization": f"Bearer {API_KEY}",
        "Content-Type":  "application/json",
    }
    payload = {
        "model": model,
        "messages": [
            {"role": "system", "content": system},
            {"role": "user",   "content": prompt}
        ],
        "temperature": temperature,
        "max_tokens": 1024,
    }

    try:
        response = requests.post(url, headers=headers, json=payload, timeout=timeout)
        status = response.status_code
        hdrs   = dict(response.headers)
        if status == 200:
            data = response.json()
            text = data.get("choices", [{}])[0].get("message", {}).get("content", "")
            return {"ok": True, "text": text, "raw": data, "status": status, "error": None, "headers": hdrs}
        else:
            # try best-effort to surface error text
            err_text = None
            try:
                err_text = response.json()
            except Exception:
                err_text = response.text
            return {"ok": False, "text": None, "raw": None, "status": status, "error": str(err_text), "headers": hdrs}
    except requests.RequestException as e:
        return {"ok": False, "text": None, "raw": None, "status": -1, "error": str(e), "headers": {}}

# %%
def normalize_text(text: str) -> str:

    text = (text or "").strip().lower()
    # Remove surrounding punctuation,extra whitespace, bullet points
    text = re.sub('[A-Z0-9]+\\)','',text)
    text = re.sub(r"[^\w\s\-']", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    # Map common synonyms used in these tests
    synonyms = {
        "unchanged": "stay the same",
        "no change": "stay the same",
        "same": "stay the same",
        "second place": "second",
        "2nd": "second",
        "first place": "first",
        "third place": "third",
    }
    return synonyms.get(text, text)

# %% [markdown]
# ### Load Dataset

# %%
PATH = '/Users/porter/Programming/final_project_tutorial_and_dev_data/dataset/cse476_final_project_dev_data.json'

with open(PATH, 'r') as file:
    dataset= pd.DataFrame(json.load(file))

# %% [markdown]
# ### Visualization

# %%
dataset['domain'].value_counts()
# Out:
# domain
# common_sense         400
# math                 300
# coding               100
# future_prediction    100
# planning             100
# Name: count, dtype: int64

# %%
dataset.loc[dataset['domain']=='common_sense']
# Out:
#                                                  input  \
# 500  Which magazine was started first Arthur's Maga...
# 501  The Oberoi family is part of a hotel company t...
# 502  Musician and satirist Allie Goertz wrote a son...
# 503    What nationality was James Henry Miller's wife?
# 504  Cadmium Chloride is slightly soluble in this c...
# ..                                                 ...
# 995  What do ugly ducklings become when they grow u...
# 996  What happens if you eat a pomegranate?\nWhat i...
# 997  What real child was raised by wolves?\nWhat is...
# 998  Can reindeer really fly?\nWhat is the best ans...
# 999  Who really collects baby teeth placed under a ...
#
#                                                 output        domain
# 500                                  Arthur's Magazine  common_sense
# 501                                              Delhi  common_sense
# 502                            President Richard Nixon  common_sense
# 503                                           American  common_sense
# 504                                            alcohol  common_sense
# ..                                                 ...           ...
# 995      Ugly ducklings become ducks when they grow up  common_sense
# 996  Nothing in particular happens when you eat a p...  common_sense
# 997      Marcos Rodriguez Pandoja was raised by wolves  common_sense
# 998                      No, reindeer can't really fly  common_sense
# 999  Baby teeth placed under a pillow are usually c...  common_sense
#
# [400 rows x 3 columns]

# %%
data:pd.Series=dataset.iloc[998]
test=call_model(data['input'])

print(data['input'])
print("\n\n============================================================\n\n")
print(test['text'])
print("\n\n============================================================\n\n")
print(data['output'])
# Out:
# Can reindeer really fly?
# What is the best answer for the question among these?
# 0) No, reindeer can't really fly
# 1) No, Santa and his reindeer aren't real
# 2) Yes, Santa and his reindeer really fly
# 3) No, reindeer can't really fly
# 4) Yes, reindeer can really fly
# 5) No, flying reindeer aren't real
#
#
# ============================================================
#
#
# 0) No, reindeer can't really fly
#
#
# ============================================================
#
#
# No, reindeer can't really fly

# %% [markdown]
# ### Base Model Scoring Cross Domain

# %%
"""Generating base model response to questions"""


model_output:list[str]=[]

for prompt in tqdm(dataset['input'],unit='request'):

    try:   
        
        response:dict[str,Any]=call_model(prompt)
        model_output.append(normalize_text(response['text']))

    except Exception as e:
        print(e)
        model_output.append(None)

dataset['model_response']=model_output
# Out:
# 100%|██████████| 1000/1000 [23:44<00:00,  1.42s/request]

# %%
dataset.head()
# Out:
#                                                input output domain  \
# 0  Let $ABCD$ be a convex quadrilateral with $AB ...    112   math
# 1  A tennis player computes her win ratio by divi...    164   math
# 2  What is the product of the real roots of the e...     20   math
# 3  In $\triangle ABC$ , $AB= 425$ , $BC=450$ , an...    306   math
# 4  How many even integers between 4000 and 7000 h...    728   math
#
#                                       model_response
# 0  we are given a convex quadrilateral abcd with ...
# 1  let x be the number of matches she won before ...
# 2                the product of the real roots is 15
# 3  we are given a triangle triangle abc with side...
# 4                                         answer 432

# %%
"""Evaluating result through comparison of answers """


compared_result:list[bool]=[]
model_eval:list[bool]=[]

for i in trange(len(dataset)):

    answer:str=normalize_text(str(dataset['output'].iloc[i]))
    model_response:str=normalize_text(str(dataset['model_response'].iloc[i]))
    
    PROMPT=f'''
        You are a strict grader who excels in differentiating a response is correct or not. If they're correct you respond with True, if not then respond with False. 
        DO NOT overthink anything more than the response itself.

        Given answer: {answer} 
        the response: {model_response} 

        Determine whether the response is correct to the answer or not
    '''
    
    model_eval.append(call_model(prompt=PROMPT)['text'])
    compared_result.append(str(answer == model_response))

dataset['result']=compared_result
dataset['model_eval']=model_eval
# Out:
# 100%|██████████| 1000/1000 [02:27<00:00,  6.76it/s]

# %%
dataset.to_csv('dataset/base_result.csv')
dataset.head()
# Out:
#                                                input output domain  \
# 0  Let $ABCD$ be a convex quadrilateral with $AB ...    112   math
# 1  A tennis player computes her win ratio by divi...    164   math
# 2  What is the product of the real roots of the e...     20   math
# 3  In $\triangle ABC$ , $AB= 425$ , $BC=450$ , an...    306   math
# 4  How many even integers between 4000 and 7000 h...    728   math
#
#                                       model_response result model_eval
# 0  we are given a convex quadrilateral abcd with ...  False      False
# 1  let x be the number of matches she won before ...  False       True
# 2                the product of the real roots is 15  False      False
# 3  we are given a triangle triangle abc with side...  False      False
# 4                                         answer 432  False      False

# %%
print(dataset['result'].value_counts())
print(dataset['model_eval'].value_counts())
# Out:
# result
# False    913
# True      87
# Name: count, dtype: int64
# model_eval
# False    758
# True     242
# Name: count, dtype: int64

# %% [markdown]
# ### EDA of Base Model Result

# %%
dataset.loc[dataset['model_eval'] != dataset['result']]
# Out:
#                                                  input  \
# 1    A tennis player computes her win ratio by divi...
# 7    Let $\mathcal{S}$ be the set $\lbrace1,2,3,\ld...
# 10   Suppose that $x,$ $y,$ and $z$ are three posit...
# 12   For how many positive integers $n$ less than o...
# 13   Jenn randomly chooses a number $J$ from $1, 2,...
# ..                                                 ...
# 953  Where can you find a real psychic?\nWhat is th...
# 955  What methods can people use to contact the dea...
# 967  Are vampires real?\nWhat is the best answer fo...
# 970  Who is the bell-ringer of Notre Dame?\nWhat is...
# 973  Who is faster in real life, a tortoise or a ha...
#
#                                                 output        domain  \
# 1                                                  164          math
# 7                                                  501          math
# 10                                                   5          math
# 12                                                 250          math
# 13                                                  29          math
# ..                                                 ...           ...
# 953                               Psychics aren't real  common_sense
# 955  There are no methods that people can use to co...  common_sense
# 967                          No, vampires are not real  common_sense
# 970                                  I have no comment  common_sense
# 973                      A hare is faster in real life  common_sense
#
#                                         model_response result model_eval
# 1    let x be the number of matches she won before ...  False       True
# 7    we are given the set mathcal s 1 2 3 ldots 10 ...  False       True
# 10   we are given the following equations 1 xyz 1 2...  False       True
# 12   we are given the identity sin t i cos t n sin ...  False       True
# 13   we are given that - jenn chooses a number j fr...  False       True
# ..                                                 ...    ...        ...
# 953  you can't find a real psychic since psychics a...  False       True
# 955  people have claimed to contact the dead but th...  False       True
# 967                           no vampires do not exist  False       True
# 970         quasimodo is the bell-ringer of notre dame  False       True
# 973                hares can run faster than tortoises  False       True
#
# [155 rows x 6 columns]

# %%
i=0
print(dataset['input'].iloc[i])
print(dataset['output'].iloc[i])
print(dataset['model_response'].iloc[i])
# Out:
# Let $ABCD$ be a convex quadrilateral with $AB = CD = 10$ , $BC = 14$ , and $AD = 2\sqrt{65}$ . Assume that the diagonals of $ABCD$ intersect at point $P$ , and that the sum of the areas of triangles $APB$ and $CPD$ equals the sum of the areas of triangles $BPC$ and $APD$ . Find the area of quadrilateral $ABCD$ .
# 112
# we are given a convex quadrilateral abcd with the following side lengths - ab 10 - cd 10 - bc 14 - ad 2 sqrt 65 also the diagonals intersect at point p and it is given that text area triangle apb text area triangle cpd text area triangle bpc text area triangle apd this implies that the diagonals divide the quadrilateral into four triangles of equal total area and the sum of the areas of opposite triangles is equal this is a key geometric property that often occurs in kites or isosceles trapezoids but here we are given specific side lengths let s denote the area of quadrilateral abcd as a then the total area is a text area triangle apb text area triangle bpc text area triangle cpd text area triangle apd from the given condition text area triangle apb text area triangle cpd text area triangle bpc text area triangle apd let s denote the left-hand side as s and the right-hand side as s as well then a s s 2s so the total area of the quadrilateral is twice the area of one of the pairs of opposite triangles now we are given that ab cd 10 and ad 2 sqrt 65 bc 14 this suggests that the quadrilateral may be symmetric in some way possibly a kite or a rhombus but not necessarily let s try to compute the area of the quadrilateral using the diagonal method we can use the formula for the area of a quadrilateral in terms of its diagonals and the angle between them text area frac 1 2 d_1 d_2 sin theta where d_1 and d_2 are the lengths of the diagonals and theta is the angle between them however we are not given the lengths of the diagonals or the angle between them so we need to find the area using another method let s try to use the coordinates method place the quadrilateral in the coordinate plane and use the given side lengths to find coordinates of the vertices then compute the area using the shoelace formula let s place point a at the origin a 0 let s place point d at 2 sqrt 65 since ad 2 sqrt 65 now we need to find coordinates of b and c such that - ab 10 - bc 14 - cd 10 let s assume b x y and c u v from ab 10 we have x 2 y 2 100 quad text from ad 2 sqrt 65 we already have d 2 sqrt 65 from cd 10 we have u - 2 sqrt 65 2 v 2 100 quad text from bc 14 we have u - x 2 v - y 2 196 quad text now we have three equations with 6 variables this is too many variables to solve directly instead let s try to find the area using the diagonal method again but with a different approach let s assume the diagonals intersect at point p and the given condition implies that the diagonals divide the quadrilateral into four triangles of equal area that is text area triangle apb text area triangle bpc text area triangle cpd text area triangle apd so the total area is a 4 times text area triangle apb let s now try
